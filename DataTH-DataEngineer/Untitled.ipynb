# %%
import pandas as pd
root_path = "C:\\Users\\Aeolus\\Desktop\\Docs\\Practice\\Python\\DataTH-DataEngineer\\stocks\\"

# %%
df_pttep_fetch = pd.read_html("https://www.set.or.th/set/historicaltrading.do?symbol=PTTEP&ssoPageId=2&language=th&country=TH")
df_pttep_fetch[0].to_csv(root_path+"pttep.csv", encoding="utf-8")
df_pttep = pd.read_csv(root_path+"pttep.csv")

# %%
df_ptt_fetch = pd.read_html("https://www.set.or.th/set/historicaltrading.do?symbol=PTT&ssoPageId=2&language=th&country=TH")
df_ptt_fetch[0].to_csv(root_path+"ptt.csv", encoding="utf-8")
df_ptt = pd.read_csv(root_path+"ptt.csv")

# %%
df_pttep
# Out:
#     Unnamed: 0      วันที่  ราคาเปิด  ราคาสูงสุด  ราคาต่ำสุด  ราคาปิด  \
# 0            0  20/11/2563     92.25       94.50       92.00    93.75
# 1            1  19/11/2563     93.00       93.50       91.50    92.25
# 2            2  18/11/2563     91.00       93.50       90.50    93.00
# 3            3  17/11/2563     91.50       93.25       91.00    91.25
# 4            4  16/11/2563     91.25       92.00       90.75    91.50
# 5            5  13/11/2563     89.00       91.00       88.50    90.25
# 6            6  12/11/2563     90.00       91.50       89.25    90.50
# 7            7  11/11/2563     91.75       92.50       89.50    91.50
# 8            8  10/11/2563     91.00       91.75       89.00    90.75
# 9            9  09/11/2563     83.50       85.25       83.25    84.00
# 10          10  06/11/2563     82.50       84.00       81.75    82.75
# 11          11  05/11/2563     82.25       83.75       81.75    82.75
# ...
